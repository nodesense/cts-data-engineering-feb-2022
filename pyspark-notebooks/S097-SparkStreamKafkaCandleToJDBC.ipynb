# %%
import os
# save using vs code
SCALA_VERSION = '2.12'
SPARK_VERSION = '3.1.3'
# Download Kafka Jar file, this for readStream.format("kafka"), "kafka" is a driver
# kafka driver code is part of Maven Jar file
# https://mvnrepository.com/artifact/org.apache.spark/spark-sql-kafka-0-10_2.12/3.1.3
# pyspark-shell shall download the jar file behind..
os.environ['PYSPARK_SUBMIT_ARGS'] = f'--packages org.apache.spark:spark-sql-kafka-0-10_{SCALA_VERSION}:{SPARK_VERSION} pyspark-shell'

# %%
# here we implement windowed candle data for 1 minute
# here we implement windowed candle data for 3 minute
# here we implement windowed candle data for 5 minute

# we use hadoop-vm as hostname, which is running on another system


#     kafka-topics  --create --bootstrap-server hadoop-vm:9092 --replication-factor 1 --partitions 1 --topic stock-ticks 
    
#     kafka-topics  --create --bootstrap-server hadoop-vm:9092 --replication-factor 1 --partitions 1 --topic candles-1min 
#     kafka-console-consumer --bootstrap-server hadoop-vm:9092 --topic  candles-1min  --from-beginning
 
#     kafka-topics  --create --bootstrap-server hadoop-vm:9092 --replication-factor 1 --partitions 1 --topic candles-3min 
#     kafka-console-consumer --bootstrap-server hadoop-vm:9092 --topic  candles-3min  --from-beginning

#     kafka-topics  --create --bootstrap-server hadoop-vm:9092 --replication-factor 1 --partitions 1 --topic candles-5min 
#     kafka-console-consumer --bootstrap-server hadoop-vm:9092 --topic  candles-5min  --from-beginning

# %%
import findspark
findspark.init()

# %%
import pyspark


from pyspark.sql import SparkSession
# spark groupBy has default setting for spark.sql.shuffle.partitions as 200
# we set to  4, should NOT be done in production 
spark = SparkSession.builder.master("local[1]")\
                            .config('spark.sql.shuffle.partitions', 4)\
                            .appName("SparkStreamingKafkaCandles").getOrCreate()

# %%
# read from kafka, here spark is consumer for kafka topic called test
# spark streaming works as dataframe/sql
# group.id is consumer group id
# subcribe is kafka topic
# "kafka" driver is not available by default with spark, we need to download it, we did on cell 1
# GROUP ID SHOULD BE CHANGED FOR EVERY PERSON 
kafkaDf = spark.readStream.format("kafka")\
  .option("kafka.bootstrap.servers", "hadoop-vm:9092")\
  .option("subscribe", "stock-ticks")\
  .option("group.id", "stock-ticks-group2")\
  .load()

# %%
# key and value are binary type, we need to CAST To STRING type
kafkaDf.printSchema()
# timestampType values
# CreateTime:  Timestamp relates to message creation time as set by a Kafka client/producer
# LogAppendTime : Timestamp relates to the time a message was appended to a Kafka log.
# UnknownType
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
# Kafka value, key are in binary format
# we need to type cast to STRING, 
# we pick only value, timestamp as we need for 10 minute window
ticksDf = kafkaDf.selectExpr("CAST(value AS STRING)", "timestamp")
ticksDf.printSchema() # we get only value as string
# Out:
# root
#  |-- value: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
# echoOnconsole = ticksDf\
#                 .writeStream\
#                 .outputMode("update")\
#                 .format("console")\
#                 .option("truncate", False)\
#                 .start() # start the query. spark will subscribe for data

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StructField, StructType, DoubleType, StringType, LongType, TimestampType

schema = StructType( [
    StructField("symbol", StringType(), True),
    StructField("price", DoubleType(), True),
    StructField("volume", LongType(), True),
    StructField("timestamp", LongType(),  True)
])

# %%
# we parse value which is JSON string to kafka struct, 
# this create a new column [replacing existing value which is string] with type
jsonDf = ticksDf.withColumn("value", F.from_json("value", schema))
jsonDf.printSchema()
# Out:
# root
#  |-- value: struct (nullable = true)
#  |    |-- symbol: string (nullable = true)
#  |    |-- price: double (nullable = true)
#  |    |-- volume: long (nullable = true)
#  |    |-- timestamp: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
# now extract all the sub fields symbol, price, volume, timestamp into data frame
# exisitng value, timestamp shall be removed. existing timestamp is value produced time, not a stock tick time
# value.timestamp that comes from producer is basically a event time
stockTickDf = jsonDf.select (F.col("value.*")) # extract all sub fields as schema
stockTickDf.printSchema()
# Out:
# root
#  |-- symbol: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- volume: long (nullable = true)
#  |-- timestamp: long (nullable = true)

# %%
stockTickDf = stockTickDf.withColumn("traded_value", F.col("price") * F.col("volume"))
stockTickDf.printSchema()
# Out:
# root
#  |-- symbol: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- volume: long (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- traded_value: double (nullable = true)

# %%
# we have data coming in stream, each record has timestamp
# we have milli seconds 1647283268253, the actual seconds Mon Mar 14 2022 14:41:08
# now we have to calculate 1 minute window, sum(volume) up to 1 minute
# after conversions, we take timestamp which is truncatd to minute instead of milli seconds, drop temp columns
stockTickDf = stockTickDf\
                .withColumn("timestampTemp", (F.col("timestamp") / 1000).cast("timestamp"))\
                .withColumn("trade_time", F.date_trunc("minute", F.col("timestampTemp")))\
                .drop("timestamp")\
                .drop("timestampTemp")\
                .withColumnRenamed("trade_time", "timestamp")
               

# echoOnconsole = stockTickDf\
#                 .writeStream\
#                 .outputMode("update")\
#                 .format("console")\
#                 .option("truncate", False)\
#                 .start() # start the query. spark will subscribe for data

# %%
# aggregate
# sum (volume), sum(traded_value), candles open, high, low, close [OHLC]
# groupBy by symbol, timestamp

# now add delayed record processing with waterMark
stockTickDf1Min = stockTickDf\
                            .withWatermark("timestamp", "1 minutes")\
                            .groupBy("symbol", F.window("timestamp", "60 seconds"))\
                          .agg( F.sum("volume").alias("volume"),\
                                F.sum("traded_value").alias("traded_value"),\
                                F.max("price").alias("high"),\
                                F.min("price").alias("low"),\
                                F.first("price").alias("first"),\
                                F.last("price").alias("last")\
                              )
stockTickDf1Min.printSchema()

# echoOnconsole = stockTickDf1Min\
#                 .writeStream\
#                 .outputMode("update")\
#                 .format("console")\
#                 .option("truncate", False)\
#                 .start() # start the query. spark will subscribe for data

# write result to kafka
# we need to publish all the field together as value
# we take all columns, convert to json string
# publish json as value to kafka

stockTickDf1MinKafka = stockTickDf1Min\
                            .selectExpr("to_json(struct(*)) AS value")

stockTickDf1MinKafka\
            .writeStream\
             .format("kafka")\
            .outputMode("update")\
             .option("kafka.bootstrap.servers", "hadoop-vm:9092")\
            .option("topic", "candles-1min")\
            .option("checkpointLocation", "file:///tmp/spark3")\
            .start()
            
# use kafka console consumer to subscrbe candles-1min, command is given in 2 nd cell
# Out:
# root
#  |-- symbol: string (nullable = true)
#  |-- window: struct (nullable = false)
#  |    |-- start: timestamp (nullable = true)
#  |    |-- end: timestamp (nullable = true)
#  |-- volume: long (nullable = true)
#  |-- traded_value: double (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: double (nullable = true)
#  |-- first: double (nullable = true)
#  |-- last: double (nullable = true)

# %%
# spark stream with batch output
# spark basically process the data as batch
# for developer convinence, we have api, that can give us finite data frame for writing to file/jsbc/db/custom coding
# process discrete output batch
# this function is called for every update/delete/comlete triggers with result data set as dataframe
# candleBatchDf is BATCH DATAFRAME
# stockTickDf1Min is STREAM DATAFRAME
def processBatchData(candleBatchDf, batch_id):
    print ("process batch called", batch_id, "writing ", candleBatchDf.count())
    # result = candleBatchDf.collect()
    # print(result)
    # candleBatchDf.show(2)
    # write to csv/json/parqeut/database /jdbc etc
    # window is nested column, has its children columns called start and end
    # start and end are part of nested window column
    # append mode will not delete existin data, instead append to existing table
    (
     candleBatchDf
        .select('*', F.col("window.*"))
        .withColumnRenamed("start", "start_time")
        .withColumnRenamed("end", "end_time")
        .drop("window")
        .write
        .mode("append")
        .format("jdbc")
        .option("url", "jdbc:mysql://localhost:3306/stockdb")
        .option("driver", "com.mysql.jdbc.Driver")
        .option("user", "team")
        .option("password", "Team1234!")
        .option("dbtable", "candle_1min")
         .save()
    )
    
stockTickDf1Min.writeStream.outputMode("append").foreachBatch(processBatchData).start()
    
# now go to mysql, check candle_1min exist
# show tables;
# select * from candle_1min
# Out:
# process batch called 0 writing  0
# process batch called 12
# process batch called 66
# process batch called 1 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 2 writing  0
# process batch called 13
# process batch called 67
# []
# []
# process batch called 3 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 68
# process batch called 14
# process batch called 4 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 69
# process batch called 15
# []
# process batch called 5 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 70
# process batch called 6 writing  0
# [Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 1), end=datetime.datetime(2022, 3, 17, 1, 2)), volume=250, traded_value=6320.0, high=50.0, low=8.0, first=12.0, last=8.0), Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 1), end=datetime.datetime(2022, 3, 17, 1, 2)), volume=210, traded_value=9150.0, high=49.0, low=38.0, first=49.0, last=45.0)]
# process batch called 16
# [Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 1), end=datetime.datetime(2022, 3, 17, 1, 2)), volume=250, traded_value=6320.0, high=50.0, low=8.0, first=12.0, last=8.0), Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 1), end=datetime.datetime(2022, 3, 17, 1, 2)), volume=210, traded_value=9150.0, high=49.0, low=38.0, first=49.0, last=45.0)]
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |MARUTI|{2022-03-17 01:01...|   250|      6320.0|50.0| 8.0| 12.0| 8.0|
# |RELAXO|{2022-03-17 01:01...|   210|      9150.0|49.0|38.0| 49.0|45.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |MARUTI|{2022-03-17 01:01...|   250|      6320.0|50.0| 8.0| 12.0| 8.0|
# |RELAXO|{2022-03-17 01:01...|   210|      9150.0|49.0|38.0| 49.0|45.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# process batch called 71
# process batch called 17
# []
# process batch called 7 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 72
# process batch called 18
# []
# []
# process batch called 8 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 73
# process batch called 19
# []
# []
# process batch called 9 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 20
# process batch called 74
# []
# []
# process batch called 10 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 75
# process batch called 21
# []
# process batch called 11 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 76
# process batch called 22
# process batch called 12 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 13 writing  2
# process batch called 23
# process batch called 77
# [Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 2), end=datetime.datetime(2022, 3, 17, 1, 3)), volume=50, traded_value=950.0, high=19.0, low=19.0, first=19.0, last=19.0), Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 2), end=datetime.datetime(2022, 3, 17, 1, 3)), volume=310, traded_value=7090.0, high=36.0, low=9.0, first=12.0, last=34.0)]
# [Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 2), end=datetime.datetime(2022, 3, 17, 1, 3)), volume=50, traded_value=950.0, high=19.0, low=19.0, first=19.0, last=19.0), Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 2), end=datetime.datetime(2022, 3, 17, 1, 3)), volume=310, traded_value=7090.0, high=36.0, low=9.0, first=12.0, last=34.0)]
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |RELAXO|{2022-03-17 01:02...|    50|       950.0|19.0|19.0| 19.0|19.0|
# |MARUTI|{2022-03-17 01:02...|   310|      7090.0|36.0| 9.0| 12.0|34.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |RELAXO|{2022-03-17 01:02...|    50|       950.0|19.0|19.0| 19.0|19.0|
# |MARUTI|{2022-03-17 01:02...|   310|      7090.0|36.0| 9.0| 12.0|34.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# process batch called 78
# process batch called 24
# []
# process batch called 14 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 79
# process batch called 25
# []
# []
# process batch called 15 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 26
# process batch called 80
# process batch called 16 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 81
# process batch called 27
# []
# []
# process batch called 17 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 82
# process batch called 28
# process batch called 18 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 83
# process batch called 29
# process batch called 19 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 20 writing  2
# process batch called 84
# process batch called 30
# [Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 3), end=datetime.datetime(2022, 3, 17, 1, 4)), volume=220, traded_value=7060.0, high=49.0, low=23.0, first=23.0, last=49.0), Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 3), end=datetime.datetime(2022, 3, 17, 1, 4)), volume=140, traded_value=4140.0, high=38.0, low=8.0, first=8.0, last=10.0)]
# [Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 3), end=datetime.datetime(2022, 3, 17, 1, 4)), volume=220, traded_value=7060.0, high=49.0, low=23.0, first=23.0, last=49.0), Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 3), end=datetime.datetime(2022, 3, 17, 1, 4)), volume=140, traded_value=4140.0, high=38.0, low=8.0, first=8.0, last=10.0)]
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |RELAXO|{2022-03-17 01:03...|   220|      7060.0|49.0|23.0| 23.0|49.0|
# |MARUTI|{2022-03-17 01:03...|   140|      4140.0|38.0| 8.0|  8.0|10.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |RELAXO|{2022-03-17 01:03...|   220|      7060.0|49.0|23.0| 23.0|49.0|
# |MARUTI|{2022-03-17 01:03...|   140|      4140.0|38.0| 8.0|  8.0|10.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# process batch called 31
# process batch called 85
# []
# []
# process batch called 21 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 86
# process batch called 32
# []
# []
# process batch called 22 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 87
# process batch called 33
# []
# []
# process batch called 23 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 34
# process batch called 88
# []
# []
# process batch called 24 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 89
# process batch called 35
# []
# process batch called 25 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 36
# process batch called 90
# []
# process batch called 26 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 91
# process batch called 27 writing  1
# [Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 4), end=datetime.datetime(2022, 3, 17, 1, 5)), volume=430, traded_value=8260.0, high=46.0, low=6.0, first=17.0, last=11.0)]
# process batch called 37
# [Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 4), end=datetime.datetime(2022, 3, 17, 1, 5)), volume=430, traded_value=8260.0, high=46.0, low=6.0, first=17.0, last=11.0)]
# +------+--------------------+------+------------+----+---+-----+----+
# |symbol|              window|volume|traded_value|high|low|first|last|
# +------+--------------------+------+------------+----+---+-----+----+
# |MARUTI|{2022-03-17 01:04...|   430|      8260.0|46.0|6.0| 17.0|11.0|
# +------+--------------------+------+------------+----+---+-----+----+
#
# +------+--------------------+------+------------+----+---+-----+----+
# |symbol|              window|volume|traded_value|high|low|first|last|
# +------+--------------------+------+------------+----+---+-----+----+
# |MARUTI|{2022-03-17 01:04...|   430|      8260.0|46.0|6.0| 17.0|11.0|
# +------+--------------------+------+------------+----+---+-----+----+
#
# process batch called 38
# process batch called 92
# []
# process batch called 28 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 93
# process batch called 39
# process batch called 29 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch calledprocess batch called  40
# 94
# process batch called 30 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 95
# process batch called 41
# process batch called 31 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 96
# process batch called 42
# process batch called 32 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 97
# process batch called 43
# []
# []
# process batch called 33 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 44
# process batch called 34 writing  2
# process batch called 98
# [Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 5), end=datetime.datetime(2022, 3, 17, 1, 6)), volume=90, traded_value=1640.0, high=42.0, low=7.0, first=17.0, last=21.0), Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 5), end=datetime.datetime(2022, 3, 17, 1, 6)), volume=140, traded_value=4180.0, high=35.0, low=17.0, first=35.0, last=17.0)]
# [Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 5), end=datetime.datetime(2022, 3, 17, 1, 6)), volume=90, traded_value=1640.0, high=42.0, low=7.0, first=17.0, last=21.0), Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 5), end=datetime.datetime(2022, 3, 17, 1, 6)), volume=140, traded_value=4180.0, high=35.0, low=17.0, first=35.0, last=17.0)]
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |RELAXO|{2022-03-17 01:05...|    90|      1640.0|42.0| 7.0| 17.0|21.0|
# |MARUTI|{2022-03-17 01:05...|   140|      4180.0|35.0|17.0| 35.0|17.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |RELAXO|{2022-03-17 01:05...|    90|      1640.0|42.0| 7.0| 17.0|21.0|
# |MARUTI|{2022-03-17 01:05...|   140|      4180.0|35.0|17.0| 35.0|17.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# process batch called 99
# process batch called 45
# []
# []
# process batch called 35 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 46
# process batch called 100
# process batch called 36 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 47
# process batch called 101
# process batch called 37 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 48
# process batch called 102
# []
# process batch called 38 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 49
# process batch called 103
# []
# []
# process batch called 39 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 104
# process batch called 50
# []
# process batch called 40 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 105
# process batch called 41 writing  2
# [Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 6), end=datetime.datetime(2022, 3, 17, 1, 7)), volume=280, traded_value=8410.0, high=50.0, low=18.0, first=34.0, last=18.0), Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 6), end=datetime.datetime(2022, 3, 17, 1, 7)), volume=150, traded_value=3700.0, high=40.0, low=17.0, first=17.0, last=40.0)]
# process batch called 51
# [Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 6), end=datetime.datetime(2022, 3, 17, 1, 7)), volume=280, traded_value=8410.0, high=50.0, low=18.0, first=34.0, last=18.0), Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 6), end=datetime.datetime(2022, 3, 17, 1, 7)), volume=150, traded_value=3700.0, high=40.0, low=17.0, first=17.0, last=40.0)]
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |MARUTI|{2022-03-17 01:06...|   280|      8410.0|50.0|18.0| 34.0|18.0|
# |RELAXO|{2022-03-17 01:06...|   150|      3700.0|40.0|17.0| 17.0|40.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |MARUTI|{2022-03-17 01:06...|   280|      8410.0|50.0|18.0| 34.0|18.0|
# |RELAXO|{2022-03-17 01:06...|   150|      3700.0|40.0|17.0| 17.0|40.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# process batch called 52
# process batch called 106
# process batch called 42 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 107
# process batch called 53
# process batch called 43 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 108
# process batch called 54
# []
# []
# process batch called 44 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 55
# process batch called 109
# []
# process batch called 45 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called process batch called 110
# 56
# []
# []
# process batch called 46 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 57
# process batch called 111
# process batch called 47 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 48 writing  2
# process batch called 58
# process batch called 112
# [Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 7), end=datetime.datetime(2022, 3, 17, 1, 8)), volume=100, traded_value=2350.0, high=40.0, low=20.0, first=23.0, last=40.0), Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 7), end=datetime.datetime(2022, 3, 17, 1, 8)), volume=250, traded_value=9250.0, high=41.0, low=31.0, first=41.0, last=31.0)]
# [Row(symbol='RELAXO', window=Row(start=datetime.datetime(2022, 3, 17, 1, 7), end=datetime.datetime(2022, 3, 17, 1, 8)), volume=100, traded_value=2350.0, high=40.0, low=20.0, first=23.0, last=40.0), Row(symbol='MARUTI', window=Row(start=datetime.datetime(2022, 3, 17, 1, 7), end=datetime.datetime(2022, 3, 17, 1, 8)), volume=250, traded_value=9250.0, high=41.0, low=31.0, first=41.0, last=31.0)]
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |RELAXO|{2022-03-17 01:07...|   100|      2350.0|40.0|20.0| 23.0|40.0|
# |MARUTI|{2022-03-17 01:07...|   250|      9250.0|41.0|31.0| 41.0|31.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# +------+--------------------+------+------------+----+----+-----+----+
# |symbol|              window|volume|traded_value|high| low|first|last|
# +------+--------------------+------+------------+----+----+-----+----+
# |RELAXO|{2022-03-17 01:07...|   100|      2350.0|40.0|20.0| 23.0|40.0|
# |MARUTI|{2022-03-17 01:07...|   250|      9250.0|41.0|31.0| 41.0|31.0|
# +------+--------------------+------+------------+----+----+-----+----+
#
# process batch called process batch called 59
# 113
# []
# process batch called 49 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 114
# process batch called 60
# []
# []
# process batch called 50 writing  0
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 61
# process batch called 115
# process batch called 51 writing  0
# []
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 62
# process batch called 116
# []
# process batch called 52 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# process batch called 63
# process batch called 117
# []
# process batch called 53 writing  0
# []
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+
#
# +------+------+------+------------+----+---+-----+----+
# |symbol|window|volume|traded_value|high|low|first|last|
# +------+------+------+------------+----+---+-----+----+
# +------+------+------+------------+----+---+-----+----+

# %%
# Write yourself, to 3 min candle with candle_3min table
# Write yourself, to 5 min candle with candle_5min table
